# %% [markdown]
# [Cloud Natural Language API: Qwik Start](https://www.cloudskillsboost.google/focuses/582?parent=catalog)

# %% [markdown]
# ![2023-05-27 13_32_17-Cloud Natural Language API_ Qwik Start _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-27 13_37_06-Cloud Natural Language API_ Qwik Start _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %%
export GOOGLE_CLOUD_PROJECT=$(gcloud config get-value core/project)

# %% [markdown]
# ![2023-05-27 13_38_02-Cloud Natural Language API_ Qwik Start _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %%
gcloud iam service-accounts create my-natlang-sa \
  --display-name "my natural language service account"

# %% [markdown]
# ![2023-05-27 13_43_08-Cloud Natural Language API_ Qwik Start _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %%
gcloud iam service-accounts keys create ~/key.json \
  --iam-account my-natlang-sa@${GOOGLE_CLOUD_PROJECT}.iam.gserviceaccount.com

# %% [markdown]
# ![2023-05-27 13_45_28-Cloud Natural Language API_ Qwik Start _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %%
export GOOGLE_APPLICATION_CREDENTIALS="/home/USER/key.json"

# %% [markdown]
# ![2023-05-27 13_46_59-Cloud Natural Language API_ Qwik Start _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-27 14_01_55-VM instances – Compute Engine – qwiklabs-gcp-01-1db… – Google Cloud console.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-27 13_47_50-Cloud Natural Language API_ Qwik Start _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %%
gcloud ml language analyze-entities --content="Michelangelo Caravaggio, Italian painter, is known for 'The Calling of Saint Matthew'." > result.json

# %% [markdown]
# ![2023-05-27 13_48_51-Cloud Natural Language API_ Qwik Start _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %%
cat result.json

# %% [markdown]
# ![2023-05-27 13_49_55-Cloud Natural Language API_ Qwik Start _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %%
{
  "entities": [
    {
      "name": "Michelangelo Caravaggio",
      "type": "PERSON",
      "metadata": {
        "wikipedia_url": "http://en.wikipedia.org/wiki/Caravaggio",
        "mid": "/m/020bg"
      },
      "salience": 0.83047235,
      "mentions": [
        {
          "text": {
            "content": "Michelangelo Caravaggio",
            "beginOffset": 0
          },
          "type": "PROPER"
        },
        {
          "text": {
            "content": "painter",
            "beginOffset": 33
          },
          "type": "COMMON"
        }
      ]
    },
    {
      "name": "Italian",
      "type": "LOCATION",
      "metadata": {
        "mid": "/m/03rjj",
        "wikipedia_url": "http://en.wikipedia.org/wiki/Italy"
      },
      "salience": 0.13870546,
      "mentions": [
        {
          "text": {
            "content": "Italian",
            "beginOffset": 25
          },
          "type": "PROPER"
        }
      ]
    },
    {
      "name": "The Calling of Saint Matthew",
      "type": "EVENT",
      "metadata": {
        "mid": "/m/085_p7",
        "wikipedia_url": "http://en.wikipedia.org/wiki/The_Calling_of_St_Matthew_(Caravaggio)"
      },
      "salience": 0.030822212,
      "mentions": [
        {
          "text": {
            "content": "The Calling of Saint Matthew",
            "beginOffset": 69
          },
          "type": "PROPER"
        }
      ]
    }
  ],
  "language": "en"
}

# %% [markdown]
# ![2023-05-27 13_52_20-Cloud Natural Language API_ Qwik Start _ Google Cloud Skills Boost.png](data:image/png;base64,...)
