# %% [markdown]
# [Video Intelligence: Qwik Start](https://www.cloudskillsboost.google/focuses/603?locale=en&parent=catalog)

# %% [markdown]
# ![2023-05-28 10_13_25-Inteligencja wideo_ Qwik Start _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-28 10_16_14-Inteligencja wideo_ Qwik Start _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %%
gcloud iam service-accounts create quickstart

# %% [markdown]
# ![2023-05-28 10_18_11-Inteligencja wideo_ Qwik Start _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %%
# gcloud iam service-accounts keys create key.json --iam-account quickstart@<your-project-123>.iam.gserviceaccount.com

# qwiklabs-gcp-04-424512955119

gcloud iam service-accounts keys create key.json --iam-account quickstart@qwiklabs-gcp-04-424512955119.iam.gserviceaccount.com

# %% [markdown]
# ![2023-05-28 10_19_39-Inteligencja wideo_ Qwik Start _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %%
gcloud auth activate-service-account --key-file key.json

# %% [markdown]
# ![2023-05-28 10_24_23-Inteligencja wideo_ Qwik Start _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %%
gcloud auth print-access-token

# %% [markdown]
# ![2023-05-28 10_25_08-Inteligencja wideo_ Qwik Start _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-28 10_25_52-Inteligencja wideo_ Qwik Start _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %% [markdown]
# `<<EOF`: To oznacza, że zaczynamy wprowadzać treść pliku. EOF jest tzw. "here document", co oznacza, że możemy wprowadzać wieloliniową treść tekstu bezpośrednio w terminalu, aż do napotkania słowa kluczowego `EOF`.

# %%
cat > request.json <<EOF
{
   "inputUri":"gs://spls/gsp154/video/train.mp4",
   "features": [
       "LABEL_DETECTION"
   ]
}
EOF

# %% [markdown]
# ![2023-05-28 10_27_52-Inteligencja wideo_ Qwik Start _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %%
curl -s -H 'Content-Type: application/json' \
    -H 'Authorization: Bearer '$(gcloud auth print-access-token)'' \
    'https://videointelligence.googleapis.com/v1/videos:annotate' \
    -d @request.json

# %% [markdown]
# ![2023-05-28 10_30_04-Inteligencja wideo_ Qwik Start _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %%
{
  "name": "projects/649695276538/locations/europe-west1/operations/1056382555564655997"
}

# %% [markdown]
# ![2023-05-28 10_31_06-Inteligencja wideo_ Qwik Start _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %%
# curl -s -H 'Content-Type: application/json' \
#     -H 'Authorization: Bearer '$(gcloud auth print-access-token)'' \
#     'https://videointelligence.googleapis.com/v1/projects/PROJECTS/locations/LOCATIONS/operations/OPERATION_NAME'



curl -s -H 'Content-Type: application/json' \
    -H 'Authorization: Bearer '$(gcloud auth print-access-token)'' \
    'https://videointelligence.googleapis.com/v1/projects/649695276538/locations/europe-west1/operations/1056382555564655997'

# %% [markdown]
# ![2023-05-28 10_32_59-Inteligencja wideo_ Qwik Start _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-05-28 10_35_47-Inteligencja wideo_ Qwik Start _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)

# %%
{
  "name": "projects/649695276538/locations/europe-west1/operations/1056382555564655997",
  "metadata": {
    "@type": "type.googleapis.com/google.cloud.videointelligence.v1.AnnotateVideoProgress",
    "annotationProgress": [
      {
        "inputUri": "/spls/gsp154/video/train.mp4",
        "progressPercent": 100,
        "startTime": "2023-05-28T08:41:00.049583Z",
        "updateTime": "2023-05-28T08:41:06.495769Z"
      }
    ]
  },
  "done": true,
  "response": {
    "@type": "type.googleapis.com/google.cloud.videointelligence.v1.AnnotateVideoResponse",
    "annotationResults": [
      {
        "inputUri": "/spls/gsp154/video/train.mp4",
        "segmentLabelAnnotations": [
          {
            "entity": {
              "entityId": "/m/01g50p",
              "description": "railroad car",
              "languageCode": "en-US"
            },
            "categoryEntities": [
              {
                "entityId": "/m/07yv9",
                "description": "vehicle",
                "languageCode": "en-US"
              }
            ],
            "segments": [
              {
                "segment": {
                  "startTimeOffset": "0s",
                  "endTimeOffset": "12.640s"
                },
                "confidence": 0.9878115
              }
            ]
          },
          {
            "entity": {
              "entityId": "/m/01prls",
              "description": "land vehicle",
              "languageCode": "en-US"
            },
            "categoryEntities": [
              {
                "entityId": "/m/07yv9",
                "description": "vehicle",
                "languageCode": "en-US"
              }
            ],
            "segments": [
              {
                "segment": {
                  "startTimeOffset": "0s",
                  "endTimeOffset": "12.640s"
                },
                "confidence": 0.9941471
              }
            ]
          },
          {
            "entity": {
              "entityId": "/m/06d_3",
              "description": "rail transport",
              "languageCode": "en-US"
            },
            "categoryEntities": [
              {
                "entityId": "/m/07bsy",
                "description": "transport",
                "languageCode": "en-US"
              }
            ],
            "segments": [
              {
                "segment": {
                  "startTimeOffset": "0s",
                  "endTimeOffset": "12.640s"
                },
                "confidence": 0.9922013
              }
            ]
          },
          {
            "entity": {
              "entityId": "/m/07jdr",
              "description": "train",
              "languageCode": "en-US"
            },
            "categoryEntities": [
              {
                "entityId": "/m/07yv9",
                "description": "vehicle",
                "languageCode": "en-US"
              }
            ],
            "segments": [
              {
                "segment": {
                  "startTimeOffset": "0s",
                  "endTimeOffset": "12.640s"
                },
                "confidence": 0.99541986
              }
            ]
          },
          {
            "entity": {
              "entityId": "/m/01vk9q",
              "description": "track",
              "languageCode": "en-US"
            },
            "segments": [
              {
                "segment": {
                  "startTimeOffset": "0s",
                  "endTimeOffset": "12.640s"
                },
                "confidence": 0.9854606
              }
            ]
          },
          {
            "entity": {
              "entityId": "/m/0db2f",
              "description": "high speed rail",
              "languageCode": "en-US"
            },
            "categoryEntities": [
              {
                "entityId": "/m/06d_3",
                "description": "rail transport",
                "languageCode": "en-US"
              }
            ],
            "segments": [
              {
                "segment": {
                  "startTimeOffset": "0s",
                  "endTimeOffset": "12.640s"
                },
                "confidence": 0.32582685
              }
            ]
          },
          {
            "entity": {
              "entityId": "/m/07bsy",
              "description": "transport",
              "languageCode": "en-US"
            },
            "segments": [
              {
                "segment": {
                  "startTimeOffset": "0s",
                  "endTimeOffset": "12.640s"
                },
                "confidence": 0.98366255
              }
            ]
          },
          {
            "entity": {
              "entityId": "/m/025s53m",
              "description": "rolling stock",
              "languageCode": "en-US"
            },
            "categoryEntities": [
              {
                "entityId": "/m/07yv9",
                "description": "vehicle",
                "languageCode": "en-US"
              }
            ],
            "segments": [
              {
                "segment": {
                  "startTimeOffset": "0s",
                  "endTimeOffset": "12.640s"
                },
                "confidence": 0.3284738
              }
            ]
          },
          {
            "entity": {
              "entityId": "/m/0py27",
              "description": "train station",
              "languageCode": "en-US"
            },
            "categoryEntities": [
              {
                "entityId": "/m/0cgh4",
                "description": "building",
                "languageCode": "en-US"
              }
            ],
            "segments": [
              {
                "segment": {
                  "startTimeOffset": "0s",
                  "endTimeOffset": "12.640s"
                },
                "confidence": 0.7776639
              }
            ]
          },
          {
            "entity": {
              "entityId": "/m/04h5c",
              "description": "locomotive",
              "languageCode": "en-US"
            },
            "categoryEntities": [
              {
                "entityId": "/m/07yv9",
                "description": "vehicle",
                "languageCode": "en-US"
              }
            ],
            "segments": [
              {
                "segment": {
                  "startTimeOffset": "0s",
                  "endTimeOffset": "12.640s"
                },
                "confidence": 0.98347765
              }
            ]
          },
          {
            "entity": {
              "entityId": "/m/05zdp",
              "description": "public transport",
              "languageCode": "en-US"
            },
            "categoryEntities": [
              {
                "entityId": "/m/07bsy",
                "description": "transport",
                "languageCode": "en-US"
              }
            ],
            "segments": [
              {
                "segment": {
                  "startTimeOffset": "0s",
                  "endTimeOffset": "12.640s"
                },
                "confidence": 0.9292841
              }
            ]
          },
          {
            "entity": {
              "entityId": "/m/0195fx",
              "description": "rapid transit",
              "languageCode": "en-US"
            },
            "categoryEntities": [
              {
                "entityId": "/m/07bsy",
                "description": "transport",
                "languageCode": "en-US"
              }
            ],
            "segments": [
              {
                "segment": {
                  "startTimeOffset": "0s",
                  "endTimeOffset": "12.640s"
                },
                "confidence": 0.8040178
              }
            ]
          },
          {
            "entity": {
              "entityId": "/m/07yv9",
              "description": "vehicle",
              "languageCode": "en-US"
            },
            "segments": [
              {
                "segment": {
                  "startTimeOffset": "0s",
                  "endTimeOffset": "12.640s"
                },
                "confidence": 0.91986895
              }
            ]
          },
          {
            "entity": {
              "entityId": "/m/0467y7",
              "description": "passenger car",
              "languageCode": "en-US"
            },
            "categoryEntities": [
              {
                "entityId": "/m/07yv9",
                "description": "vehicle",
                "languageCode": "en-US"
              }
            ],
            "segments": [
              {
                "segment": {
                  "startTimeOffset": "0s",
                  "endTimeOffset": "12.640s"
                },
                "confidence": 0.782828
              }
            ]
          }
        ],
        "shotLabelAnnotations": [
          {
            "entity": {
              "entityId": "/m/025s53m",
              "description": "rolling stock",
              "languageCode": "en-US"
            },
            "categoryEntities": [
              {
                "entityId": "/m/07yv9",
                "description": "vehicle",
                "languageCode": "en-US"
              }
            ],
            "segments": [
              {
                "segment": {
                  "startTimeOffset": "0s",
                  "endTimeOffset": "12.640s"
                },
                "confidence": 0.3212573
              }
            ]
          },
          {
            "entity": {
              "entityId": "/m/0py27",
              "description": "train station",
              "languageCode": "en-US"
            },
            "categoryEntities": [
              {
                "entityId": "/m/0cgh4",
                "description": "building",
                "languageCode": "en-US"
              }
            ],
            "segments": [
              {
                "segment": {
                  "startTimeOffset": "0s",
                  "endTimeOffset": "12.640s"
                },
                "confidence": 0.7776639
              }
            ]
          },
          {
            "entity": {
              "entityId": "/m/04h5c",
              "description": "locomotive",
              "languageCode": "en-US"
            },
            "categoryEntities": [
              {
                "entityId": "/m/07yv9",
                "description": "vehicle",
                "languageCode": "en-US"
              }
            ],
            "segments": [
              {
                "segment": {
                  "startTimeOffset": "0s",
                  "endTimeOffset": "12.640s"
                },
                "confidence": 0.98347765
              }
            ]
          },
          {
            "entity": {
              "entityId": "/m/05zdp",
              "description": "public transport",
              "languageCode": "en-US"
            },
            "categoryEntities": [
              {
                "entityId": "/m/07bsy",
                "description": "transport",
                "languageCode": "en-US"
              }
            ],
            "segments": [
              {
                "segment": {
                  "startTimeOffset": "0s",
                  "endTimeOffset": "12.640s"
                },
                "confidence": 0.92998904
              }
            ]
          },
          {
            "entity": {
              "entityId": "/m/0195fx",
              "description": "rapid transit",
              "languageCode": "en-US"
            },
            "categoryEntities": [
              {
                "entityId": "/m/07bsy",
                "description": "transport",
                "languageCode": "en-US"
              }
            ],
            "segments": [
              {
                "segment": {
                  "startTimeOffset": "0s",
                  "endTimeOffset": "12.640s"
                },
                "confidence": 0.811784
              }
            ]
          },
          {
            "entity": {
              "entityId": "/m/07yv9",
              "description": "vehicle",
              "languageCode": "en-US"
            },
            "segments": [
              {
                "segment": {
                  "startTimeOffset": "0s",
                  "endTimeOffset": "12.640s"
                },
                "confidence": 0.9223539
              }
            ]
          },
          {
            "entity": {
              "entityId": "/m/0467y7",
              "description": "passenger car",
              "languageCode": "en-US"
            },
            "categoryEntities": [
              {
                "entityId": "/m/07yv9",
                "description": "vehicle",
                "languageCode": "en-US"
              }
            ],
            "segments": [
              {
                "segment": {
                  "startTimeOffset": "0s",
                  "endTimeOffset": "12.640s"
                },
                "confidence": 0.782828
              }
            ]
          },
          {
            "entity": {
              "entityId": "/m/01g50p",
              "description": "railroad car",
              "languageCode": "en-US"
            },
            "categoryEntities": [
              {
                "entityId": "/m/07yv9",
                "description": "vehicle",
                "languageCode": "en-US"
              }
            ],
            "segments": [
              {
                "segment": {
                  "startTimeOffset": "0s",
                  "endTimeOffset": "12.640s"
                },
                "confidence": 0.98800284
              }
            ]
          },
          {
            "entity": {
              "entityId": "/m/01prls",
              "description": "land vehicle",
              "languageCode": "en-US"
            },
            "categoryEntities": [
              {
                "entityId": "/m/07yv9",
                "description": "vehicle",
                "languageCode": "en-US"
              }
            ],
            "segments": [
              {
                "segment": {
                  "startTimeOffset": "0s",
                  "endTimeOffset": "12.640s"
                },
                "confidence": 0.9941471
              }
            ]
          },
          {
            "entity": {
              "entityId": "/m/06d_3",
              "description": "rail transport",
              "languageCode": "en-US"
            },
            "categoryEntities": [
              {
                "entityId": "/m/07bsy",
                "description": "transport",
                "languageCode": "en-US"
              }
            ],
            "segments": [
              {
                "segment": {
                  "startTimeOffset": "0s",
                  "endTimeOffset": "12.640s"
                },
                "confidence": 0.9922013
              }
            ]
          },
          {
            "entity": {
              "entityId": "/m/07jdr",
              "description": "train",
              "languageCode": "en-US"
            },
            "categoryEntities": [
              {
                "entityId": "/m/07yv9",
                "description": "vehicle",
                "languageCode": "en-US"
              }
            ],
            "segments": [
              {
                "segment": {
                  "startTimeOffset": "0s",
                  "endTimeOffset": "12.640s"
                },
                "confidence": 0.99541986
              }
            ]
          },
          {
            "entity": {
              "entityId": "/m/01vk9q",
              "description": "track",
              "languageCode": "en-US"
            },
            "segments": [
              {
                "segment": {
                  "startTimeOffset": "0s",
                  "endTimeOffset": "12.640s"
                },
                "confidence": 0.9854606
              }
            ]
          },
          {
            "entity": {
              "entityId": "/m/0db2f",
              "description": "high speed rail",
              "languageCode": "en-US"
            },
            "categoryEntities": [
              {
                "entityId": "/m/06d_3",
                "description": "rail transport",
                "languageCode": "en-US"
              }
            ],
            "segments": [
              {
                "segment": {
                  "startTimeOffset": "0s",
                  "endTimeOffset": "12.640s"
                },
                "confidence": 0.32582685
              }
            ]
          },
          {
            "entity": {
              "entityId": "/m/07bsy",
              "description": "transport",
              "languageCode": "en-US"
            },
            "segments": [
              {
                "segment": {
                  "startTimeOffset": "0s",
                  "endTimeOffset": "12.640s"
                },
                "confidence": 0.98366255
              }
            ]
          }
        ],
        "segment": {
          "startTimeOffset": "0s",
          "endTimeOffset": "12.640s"
        }
      }
    ]
  }
}
student_01_b9308a6c8567@cloudshell:~ (qwiklabs-gcp-04-424512955119)$
